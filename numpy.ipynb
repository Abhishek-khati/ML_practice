# %%
import numpy as np

# %%
a=np.array([2,3,4,5,6,9])
c=np.array([4,6,7,4,8,2])

# %%
a+c
# Out:
# array([ 6,  9, 11,  9, 14, 11])

# %%
a<5
# Out:
# array([ True,  True,  True, False, False, False])

# %%
np.ones(6)
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
np.concatenate((a,c))
# Out:
# array([2, 3, 4, 5, 6, 9, 4, 6, 7, 4, 8, 2])

# %%
a*2
# Out:
# array([ 4,  6,  8, 10, 12, 18])

# %%
a*c
# Out:
# array([ 8, 18, 28, 20, 48, 18])

# %%
a=np.reshape(a,(3,2))
c=np.reshape(c,(3,2))

# %%
a
# Out:
# array([[2, 3],
#        [4, 5],
#        [6, 9]])

# %%
c
# Out:
# array([[4, 6],
#        [7, 4],
#        [8, 2]])

# %%
a*c
# Out:
# array([[ 8, 18],
#        [28, 20],
#        [48, 18]])

# %%
np.random.randn(10)
# Out:
# array([ 0.92256747,  1.03593512,  0.88025238, -0.12328054, -0.72662715,
#        -0.07697551,  1.45464664,  1.33261347, -0.21300527,  1.64546262])

# %%
np.random.randint(4)
# Out:
# 3

# %%
np.random.rand(3)
# Out:
# array([0.10537373, 0.22181917, 0.73015205])

# %%
arr=np.linspace(1,15,4) # gives value between 1 and 15 with the gap of 4)
arr
# Out:
# array([ 1.        ,  5.66666667, 10.33333333, 15.        ])

# %%
a.shape
# Out:
# (3, 2)

# %%
a.sum(axis=1)[0] # row axis =1 and column axis =0
# Out:
# 5

# %%
h=np.array([[4,5,5],[4,7,8]])

# %%
h.flatten()
# Out:
# array([4, 5, 5, 4, 7, 8])

# %%
g=np.array([[8,0,4],[3,5,8]])

# %%
g.ravel() # it is memeory efficient than flatten
# Out:
# array([8, 0, 4, 3, 5, 8])

# %%
a1=np.array([1,2,3,4,5,6])

# %%
a1*10
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
A = np.array([[2, 4],
              [6, 8]])

B = np.array([[1, 3],
              [5, 7]])

print(A @ B)# this for matrix multification
print(A*B) # this is for simple multiplication
# Out:
# [[22 34]
#  [46 74]]
# [[ 2 12]
#  [30 56]]

# %%
a.T #it creates transpose
# Out:
# array([[2, 4, 6],
#        [3, 5, 9]])

# %%
np.eye(3) # it creates identity matrix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
