# %%
import pandas as pd
df=pd.read_csv("D:\Titanic-Dataset.csv")
#how data looks like
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 18            19         0       3
# 485          486         0       3
# 150          151         0       2
# 841          842         0       2
# 218          219         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 485                             Lefebre, Miss. Jeannie  female   NaN      3
# 150                         Bateman, Rev. Robert James    male  51.0      0
# 841                           Mudd, Mr. Thomas Charles    male  16.0      0
# 218                              Bazzani, Miss. Albina  female  32.0      0
#
#      Parch       Ticket     Fare Cabin Embarked
# 18       0       345763  18.0000   NaN        S
# 485      1         4133  25.4667   NaN        S
# 150      0  S.O.P. 1166  12.5250   NaN        S
# 841      0  S.O./P.P. 3  10.5000   NaN        S
# 218      0        11813  76.2917   D15        C

# %%
#How big is data
df.shape
# Out:
# (891, 12)

# %%
df.info() #datatype of the  columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()  #counting of null values in the column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#how does the data mathematically look like
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum() # counting of rows which have duplicated values
# Out:
# 0

# %%
df.corr(numeric_only=True)["Survived"] # correlation of the columns with each other
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
